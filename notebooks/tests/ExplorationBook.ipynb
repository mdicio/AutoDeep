# %%
import pandas as pd
import numpy as np
import ast

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv(r"../output/kfold.csv")

# %%
# List of metric names
metric_names = ["lift",
    "f1",
    "mse",
    "accuracy",
    "recall",
    "precision",
    "roc_auc",
    "area_under_pr",
    "r2_score",
    "rmse"
]
dataset = df.copy()
# Create columns based on metric names
# Convert string representations to dictionaries
dataset["output_metrics"] = dataset["output_metrics"].apply(ast.literal_eval)
dataset["run_time"] = dataset["run_time"].apply(lambda x: np.round(x/60, 2))
# Create columns based on metric names
for metric in metric_names:
    dataset[metric] = dataset["output_metrics"].apply(
        lambda x: x.get(metric) if isinstance(x, dict) else np.nan
    )
    dataset[f"{metric}_std"] = dataset[metric].apply(
        lambda x: np.std(x) if isinstance(x, list) else np.nan
    )
    dataset[metric] = dataset[metric].apply(
        lambda x: np.average(x) if isinstance(x, list) else np.nan
    )

base_cols   = [
    "dataset",
    "model",
    "run_time",
    "eval_metric",
    "best_score",
    "score_std",
    "output_metrics"]

base_cols += [i for i in metric_names]
base_cols += [i+"_std" for i in metric_names]

dataset = dataset[base_cols]

# %%
tomax = {
    "mse": False,
    "rmse": False,
    "accuracy": True,
    "recall": True,
    "precision": True,
    "roc_auc": True,
    "area_under_pr": True,
    "lift": True,
    "f1": True,
    "r2_score": True,
}

# Define a function to select the first row based on whether to maximize or minimize the "best_score"
def select_first_row(group):
    metric = group["eval_metric"].iloc[0]
    ascending = not tomax.get(metric, True)  # If metric not in tomax, assume True (maximize)
    return group.sort_values(by="best_score", ascending=ascending).iloc[0]


# Apply the function to each group
filtered_df = dataset.groupby(["dataset", "model", "eval_metric"]).apply(select_first_row)
# Reset the index to get a new DataFrame
filtered_df = filtered_df.reset_index(drop=True)
# Find the rows that maximize the specified metric for each dataset


# Sort the DataFrame based on whether the metric is to be maximized or not
filtered_df["ascending"] = filtered_df["eval_metric"].map({k:not v for k,v in tomax.items()})  # Create a new column for ascending order
dfmax = filtered_df.loc[filtered_df["ascending"] == False].sort_values(by=["dataset", "eval_metric", "best_score"], ascending=[False, False, False])
dfmin = filtered_df.loc[filtered_df["ascending"] == True].sort_values(by=["dataset", "eval_metric", "best_score"], ascending=[False, False, True])

best_df = pd.concat([dfmax,dfmin])
best_df.drop(columns=["ascending"], inplace=True)
best_df.head(20)
# Out:
#     dataset     model  run_time eval_metric  best_score  score_std  \
# 16  titanic       xgb      0.01        lift    2.483185   0.124336
# 11  titanic       mlp      0.09        lift    2.207297   0.212164
# 13  titanic    resnet      5.03        lift    2.145494   0.505266
# 15  titanic       xgb      0.12    accuracy    0.832754   0.028829
# 9   titanic  catboost      1.08    accuracy    0.830513   0.028147
# 14  titanic    s1dcnn     68.46    accuracy    0.805825   0.019104
# 12  titanic    resnet     86.83    accuracy    0.805825   0.021586
# 10  titanic       mlp      1.35    accuracy    0.804708   0.010990
# 5      iris       mlp      0.07    accuracy    0.966667   0.042164
# 4      iris  catboost      0.58    accuracy    0.960000   0.038873
# 6      iris    resnet     20.54    accuracy    0.960000   0.053333
# 7      iris    s1dcnn     14.67    accuracy    0.960000   0.048990
# 8      iris       xgb      0.05    accuracy    0.946667   0.026667
# 3   housing       xgb      3.16    r2_score    0.859626   0.006905
# 1   housing  catboost      2.61    r2_score    0.855337   0.007054
# 2   housing       mlp     29.69    r2_score    0.814026   0.004793
# 0     heloc       xgb      0.18     roc_auc    0.796683   0.006301
#
#                                        output_metrics      lift        f1  \
# 16  {'recall': [0.6956521739130435, 0.661764705882...  2.483185  0.732687
# 11  {'recall': [0.7246376811594203, 0.647058823529...  2.207297  0.679311
# 13  {'recall': [0.855072463768116, 0.8088235294117...  2.145494  0.665373
# 15  {'recall': [0.7246376811594203, 0.764705882352...       NaN  0.765091
# 9   {'recall': [0.7246376811594203, 0.764705882352...       NaN  0.766997
# 14  {'recall': [0.6231884057971014, 0.676470588235...       NaN  0.721057
# 12  {'recall': [0.6811594202898551, 0.764705882352...       NaN  0.722766
# 10  {'recall': [0.6956521739130435, 0.691176470588...       NaN  0.726242
# 5   {'accuracy': [1.0, 1.0, 0.9333333333333333, 1....       NaN  0.966482
# 4   {'accuracy': [1.0, 0.9666666666666667, 0.93333...       NaN  0.959798
# 6   {'accuracy': [1.0, 1.0, 0.8666666666666667, 1....       NaN  0.958754
# 7   {'accuracy': [1.0, 0.9666666666666667, 0.86666...       NaN  0.959614
# 8   {'accuracy': [0.9666666666666667, 0.9666666666...       NaN  0.946432
# 3   {'mse': [0.1829176045330687, 0.185832281478392...       NaN       NaN
# 1   {'mse': [0.1938205087773879, 0.192307146912765...       NaN       NaN
# 2   {'mse': [0.2448608529482562, 0.250087402867852...       NaN       NaN
# 0   {'recall': [0.7692307692307693, 0.773809523809...       NaN  0.749417
#
#          mse  accuracy    recall  precision   roc_auc  area_under_pr  \
# 16       NaN  0.813703  0.666539   0.816965  0.862084       0.832333
# 11       NaN  0.756431  0.672336   0.687374  0.732221       0.698215
# 13       NaN  0.728423  0.713683   0.644341  0.806334       0.743390
# 15       NaN  0.832754  0.710529   0.829900       NaN       0.702147
# 9        NaN  0.830513  0.727962   0.811079       NaN       0.696238
# 14       NaN  0.805825  0.655200   0.810598  0.816381       0.661586
# 12       NaN  0.805825  0.669650   0.797970  0.850005       0.659132
# 10       NaN  0.804708  0.675533   0.789479       NaN       0.656769
# 5        NaN  0.966667       NaN        NaN       NaN            NaN
# 4        NaN  0.960000       NaN        NaN       NaN            NaN
# 6        NaN  0.960000       NaN        NaN       NaN            NaN
# 7        NaN  0.960000       NaN        NaN       NaN            NaN
# 8        NaN  0.946667       NaN        NaN       NaN            NaN
# 3   0.186786       NaN       NaN        NaN       NaN            NaN
# 1   0.192517       NaN       NaN        NaN       NaN            NaN
# 2   0.247566       NaN       NaN        NaN       NaN            NaN
# 0        NaN  0.727987  0.779080   0.722182  0.796683       0.677869
#
#     r2_score      rmse  lift_std    f1_std   mse_std  accuracy_std  \
# 16       NaN       NaN  0.124336  0.030082       NaN      0.018823
# 11       NaN       NaN  0.212164  0.041073       NaN      0.030849
# 13       NaN       NaN  0.505266  0.052284       NaN      0.040085
# 15       NaN       NaN       NaN  0.041891       NaN      0.028829
# 9        NaN       NaN       NaN  0.040616       NaN      0.028147
# 14       NaN       NaN       NaN  0.026145       NaN      0.019104
# 12       NaN       NaN       NaN  0.049331       NaN      0.021586
# 10       NaN       NaN       NaN  0.014483       NaN      0.010990
# 5        NaN       NaN       NaN  0.042350       NaN      0.042164
# 4        NaN       NaN       NaN  0.039040       NaN      0.038873
# 6        NaN       NaN       NaN  0.055351       NaN      0.053333
# 7        NaN       NaN       NaN  0.049657       NaN      0.048990
# 8        NaN       NaN       NaN  0.026785       NaN      0.026667
# 3   0.859626  0.432096       NaN       NaN  0.007679           NaN
# 1   0.855337  0.438659       NaN       NaN  0.008439           NaN
# 2   0.814026  0.497510       NaN       NaN  0.007018           NaN
# 0        NaN       NaN       NaN  0.005335       NaN      0.008977
#
#     recall_std  precision_std  roc_auc_std  area_under_pr_std  r2_score_std  \
# 16    0.041865       0.045743     0.024421           0.017240           NaN
# 11    0.043343       0.047081     0.038267           0.038188           NaN
# 13    0.127959       0.070147     0.048077           0.100811           NaN
# 15    0.044901       0.047407          NaN           0.047687           NaN
# 9     0.043755       0.042184          NaN           0.044844           NaN
# 14    0.052985       0.066864     0.010880           0.035078           NaN
# 12    0.090171       0.047494     0.022843           0.035335           NaN
# 10    0.035299       0.045488          NaN           0.022011           NaN
# 5          NaN            NaN          NaN                NaN           NaN
# 4          NaN            NaN          NaN                NaN           NaN
# 6          NaN            NaN          NaN                NaN           NaN
# 7          NaN            NaN          NaN                NaN           NaN
# 8          NaN            NaN          NaN                NaN           NaN
# 3          NaN            NaN          NaN                NaN      0.006905
# 1          NaN            NaN          NaN                NaN      0.007054
# 2          NaN            NaN          NaN                NaN      0.004793
# 0     0.007916       0.013530     0.006301           0.009481           NaN
#
#     rmse_std
# 16       NaN
# 11       NaN
# 13       NaN
# 15       NaN
# 9        NaN
# 14       NaN
# 12       NaN
# 10       NaN
# 5        NaN
# 4        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 3   0.008891
# 1   0.009723
# 2   0.007032
# 0        NaN
